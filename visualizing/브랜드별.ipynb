# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import matplotlib
import matplotlib.font_manager as fm

import matplotlib.pyplot as plt
from matplotlib import rc  
rc('font', family='AppleGothic') 	
plt.rcParams['axes.unicode_minus'] = False   

import matplotlib.ticker as ticker

# %%
df = pd.read_csv("/Users/zzgr/Desktop/zzgrSandaeteuk/PROJECT GAS STATION/데이터/정리 데이터/주유소 데이터 위도 경도 추가본.csv", index_col=0)
df
# Out:
#           지역                    상호                    주소      상표  \
# 0      서울특별시  재건에너지 재정제2주유소 고속셀프지점  서울특별시 강동구  천호대로       현대오일뱅크
# 1      서울특별시               방아다리주유소        서울 강동구 동남로       SK에너지
# 2      서울특별시     현대오일뱅크㈜직영 명일셀프주유소        서울 강동구 고덕로      현대오일뱅크
# 3      서울특별시                구천면주유소       서울 강동구 구천면로      현대오일뱅크
# 4      서울특별시          대성석유(주)길동주유소           서울 강동구 천호대로   GS칼텍스
# ...      ...                   ...                   ...     ...
# 10983  서울특별시    (주)새서울네트웍스 제이제이주유소            서울 강남구 언주로  현대오일뱅크
# 10984  서울특별시                 대청주유소        서울 강남구 개포로       SK에너지
# 10985  서울특별시               SK논현주유소        서울 강남구 논현로       SK에너지
# 10986  서울특별시               갤러리아주유소           서울 강남구 압구정로   SK에너지
# 10987  서울특별시        (주)만정에너지 삼보주유소       서울 강남구 봉은사로       GS칼텍스
#
#                전화번호 셀프여부  고급휘발유   휘발유    경유  실내등유        lat        long
# 0       02-487-2030    Y      0  1709  1829     0  37.537785  127.126548
# ...

# %%
regionalbrandcount = df.groupby(['지역','상표'])['주소'].count().reset_index()

# %%
sns.catplot(data=regionalbrandcount, x='상표',y='주소',col='지역',col_wrap=3, kind='bar')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.figure(figsize=(20,15))
sns.catplot(data=gas2,y='경유',x="상표",kind='bar'
           ,height=10
           ,alpha=0.7
           
           )
plt.grid(axis='y')

plt.title('브랜드별 가격 비교')
# plt.yticks([i for i in range(0,27, 3)])
plt.savefig('브랜드별 가격비교_경유.png', dpi=100,facecolor='w',bbox_inches='tight')

# %%
pd.to_csv("/Users/bangjiyun/Desktop/'price_group2'",encoding='cp949')

# %% [markdown]
# # -- 밀도율 구하기

# %%
stations_count = a.apply(lambda x: x*0.01)
stations_count.to_csv('brand_density.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [56], in <cell line: 1>()
# ----> 1 stations_count = a.apply(lambda x: x*0.01)
#       2 stations_count.to_csv('brand_density.csv')
#
# NameError: name 'a' is not defined

# %%
df1 = df[df['휘발유'] != 0]
df1 = df[df['경유'] != 0]
df1
# Out:
#           지역                    상호                            주소      상표  \
# 0      서울특별시  재건에너지 재정제2주유소 고속셀프지점  서울특별시 강동구  천호대로 1246 (둔촌제2동)  현대오일뱅크
# 1      서울특별시               방아다리주유소          서울 강동구 동남로 811 (명일동)   SK에너지
# 2      서울특별시     현대오일뱅크㈜직영 명일셀프주유소          서울 강동구 고덕로 168 (명일동)  현대오일뱅크
# 3      서울특별시                구천면주유소         서울 강동구 구천면로 357 (암사동)  현대오일뱅크
# 4      서울특별시          대성석유(주)길동주유소              서울 강동구 천호대로 1168   GS칼텍스
# ...      ...                   ...                           ...     ...
# 10983  서울특별시    (주)새서울네트웍스 제이제이주유소                서울 강남구 언주로 716  현대오일뱅크
# 10984  서울특별시                 대청주유소          서울 강남구 개포로 654 (일원동)   SK에너지
# 10985  서울특별시               SK논현주유소          서울 강남구 논현로 747 (논현동)   SK에너지
# 10986  서울특별시               갤러리아주유소               서울 강남구 압구정로 426   SK에너지
# 10987  서울특별시        (주)만정에너지 삼보주유소         서울 강남구 봉은사로 433 (삼성동)   GS칼텍스
#
#                전화번호 셀프여부  고급휘발유   휘발유    경유  실내등유
# ...

# %%
pd.DataFrame(df1.groupby('상표')['상호'].count()).to_('brand_density.csv')

# %%
import matplotlib.pyplot as plt

ratio = [21.65, 6.72, 21.25, 29.23, 1.89, 4.38, 1.23, 23.53]
labels = ['GS칼텍스', 'NH-OIL', 'S-OIL', 'SK에너지','알뜰(ex)','알뜰주유소','자가상표','현대오일뱅크']
explode = [0,0,0,0.08,0,0,0,0]
colors = ['mintcream','#edbb99','#e59866','#D35400','#F6DDCC','#EDBB99','#F6DDCC','#E59866']
wedgeprops={'width': 0.8, 'edgecolor': 'w', 'linewidth': 1}

plt.figure(figsize=(10,13))
plt.pie(ratio, labels=labels, autopct='%.1f%%', startangle=260, counterclock=False, explode=explode, shadow=True,wedgeprops=wedgeprops)
plt.savefig('상호별 주유소 밀도율 비교.png', dpi=100,facecolor='w',bbox_inches='tight')

# %%
pd.to_csv("/Users/bangjiyun/Desktop/'brand_density'",encoding='cp949')

# %%
df
# Out:
#           지역                    상호                            주소      상표  \
# 0      서울특별시  재건에너지 재정제2주유소 고속셀프지점  서울특별시 강동구  천호대로 1246 (둔촌제2동)  현대오일뱅크
# 1      서울특별시               방아다리주유소          서울 강동구 동남로 811 (명일동)   SK에너지
# 2      서울특별시     현대오일뱅크㈜직영 명일셀프주유소          서울 강동구 고덕로 168 (명일동)  현대오일뱅크
# 3      서울특별시                구천면주유소         서울 강동구 구천면로 357 (암사동)  현대오일뱅크
# 4      서울특별시          대성석유(주)길동주유소              서울 강동구 천호대로 1168   GS칼텍스
# ...      ...                   ...                           ...     ...
# 10983  서울특별시    (주)새서울네트웍스 제이제이주유소                서울 강남구 언주로 716  현대오일뱅크
# 10984  서울특별시                 대청주유소          서울 강남구 개포로 654 (일원동)   SK에너지
# 10985  서울특별시               SK논현주유소          서울 강남구 논현로 747 (논현동)   SK에너지
# 10986  서울특별시               갤러리아주유소               서울 강남구 압구정로 426   SK에너지
# 10987  서울특별시        (주)만정에너지 삼보주유소         서울 강남구 봉은사로 433 (삼성동)   GS칼텍스
#
#                전화번호 셀프여부  고급휘발유   휘발유    경유  실내등유
# ...

# %%
df1 = df[df['휘발유'] != 0]
df1
df2 = df[df['경유'] != 0]
df2
# Out:
#           지역                    상호                            주소      상표  \
# 0      서울특별시  재건에너지 재정제2주유소 고속셀프지점  서울특별시 강동구  천호대로 1246 (둔촌제2동)  현대오일뱅크
# 1      서울특별시               방아다리주유소          서울 강동구 동남로 811 (명일동)   SK에너지
# 2      서울특별시     현대오일뱅크㈜직영 명일셀프주유소          서울 강동구 고덕로 168 (명일동)  현대오일뱅크
# 3      서울특별시                구천면주유소         서울 강동구 구천면로 357 (암사동)  현대오일뱅크
# 4      서울특별시          대성석유(주)길동주유소              서울 강동구 천호대로 1168   GS칼텍스
# ...      ...                   ...                           ...     ...
# 10983  서울특별시    (주)새서울네트웍스 제이제이주유소                서울 강남구 언주로 716  현대오일뱅크
# 10984  서울특별시                 대청주유소          서울 강남구 개포로 654 (일원동)   SK에너지
# 10985  서울특별시               SK논현주유소          서울 강남구 논현로 747 (논현동)   SK에너지
# 10986  서울특별시               갤러리아주유소               서울 강남구 압구정로 426   SK에너지
# 10987  서울특별시        (주)만정에너지 삼보주유소         서울 강남구 봉은사로 433 (삼성동)   GS칼텍스
#
#                전화번호 셀프여부  고급휘발유   휘발유    경유  실내등유
# ...

# %%
# df1 = df[['상호','상표']]
pd.DataFrame(df1.groupby('상표').count()['휘발유'])
# Out:
#          휘발유
# 상표
# GS칼텍스   2160
# NH-OIL   672
# S-OIL   2112
# SK에너지   2914
# 알뜰(ex)   189
# 알뜰주유소    438
# 자가상표     115
# 현대오일뱅크  2344

# %%
pd.DataFrame(df1.groupby('상표').count())
# Out:
#           지역    상호    주소  전화번호  셀프여부  고급휘발유   휘발유    경유  실내등유
# 상표
# GS칼텍스   2160  2160  2160  2160  2160   2160  2160  2160  2160
# NH-OIL   672   672   672   672   672    672   672   672   672
# S-OIL   2112  2112  2112  2112  2112   2112  2112  2112  2112
# SK에너지   2914  2914  2914  2914  2914   2914  2914  2914  2914
# 알뜰(ex)   189   189   189   189   189    189   189   189   189
# 알뜰주유소    438   438   438   438   438    438   438   438   438
# 자가상표     115   115   115   115   115    115   115   115   115
# 현대오일뱅크  2344  2344  2344  2344  2344   2344  2344  2344  2344

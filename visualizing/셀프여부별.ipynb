# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import matplotlib
import matplotlib.font_manager as fm

import matplotlib.pyplot as plt
from matplotlib import rc  
rc('font', family='AppleGothic') 	
plt.rcParams['axes.unicode_minus'] = False

# %%
cd
# Out:
# /Users/bangjiyun

# %%
df = pd.read_csv("/Users/bangjiyun/과제/basic/Merged_Stations.csv")
df = df.drop(columns=['Unnamed: 0'])
df
# Out:
#          지역                상호                        주소      상표          전화번호  \
# 0       강원도    백두에너지(주) 오정주유소           강원 강릉시 경강로 2344   S-OIL  033-652-9276
# 1       강원도             강변주유소         강원 춘천시 서면 경춘로 701  현대오일뱅크  033-263-2210
# 2       강원도        SK직영 부안주유소      강원 춘천시 후석로 239 (후평동)   SK에너지  033-257-5151
# 3       강원도             예일주유소     강원 춘천시 남산면 김유정로 295-4   SK에너지  033-263-7756
# 4       강원도             신포주유소       강원 춘천시 사북면 영서로 4927   S-OIL  033-243-5188
# ...     ...               ...                       ...     ...           ...
# 12841  충청북도             문암주유소        충북 음성군 원남면 충청대로 60   S-OIL  043-872-8951
# 12842  충청북도           감곡직영주유소       충북 음성군 감곡면 음성로 2479   S-OIL  043-881-8787
# 12843  충청북도            오갑산주유소        충북 음성군 감곡면 북부로 547   SK에너지  043-877-8500
# 12844  충청북도         성본산단셀프주유소        충북 음성군 대소면 대금로 906  현대오일뱅크  043-883-5155
# 12845  충청북도  현대오일뱅크㈜직영 보라매주유소  충북 청주시 상당구 단재로 332 (방서동)  현대오일뱅크  043-297-8168
#
# ...

# %%
a = df.groupby("셀프여부")["휘발유","경유"].mean()
a.to_csv('self_휘발유.csv')
# a=a.reset_index()
# sns.catplot(data=a,col='셀프여부',kind='bar')
# plt.savefig('셀프여부별 가격비교.png', dpi=100,facecolor='w',bbox_inches='tight')
# Out:
# /var/folders/0_/gqzzfsxd1391jx3x0k4j_lhm0000gn/T/ipykernel_29544/2830531144.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   a = df.groupby("셀프여부")["휘발유","경유"].mean()

# %%
df['주소'].str.split().apply(lambda x: x[:-1])
# Out:
# 0        [서울특별시, 강동구, 천호대로]
# 1            [서울, 강동구, 동남로]
# 2            [서울, 강동구, 고덕로]
# 3           [서울, 강동구, 구천면로]
# 4                 [서울, 강동구]
#                 ...
# 10983             [서울, 강남구]
# 10984        [서울, 강남구, 개포로]
# 10985        [서울, 강남구, 논현로]
# 10986             [서울, 강남구]
# 10987       [서울, 강남구, 봉은사로]
# Name: 주소, Length: 10988, dtype: object

# %%
df_address = df['주소']

# %%
df_address
loc=[]
for i in df_address:
    loc.append(i.split(" ")[:-1])
df_address = loc    
df_address
# Out:
# [['서울특별시', '강동구', '', '천호대로'],
#  ['서울', '강동구', '동남로'],
#  ['서울', '강동구', '고덕로'],
#  ['서울', '강동구', '구천면로'],
#  ['서울', '강동구'],
#  ['서울', '강동구', '고덕로'],
#  ['서울', '강동구', '천호대로'],
#  ['서울', '강동구', '', '상일로'],
#  ['서울', '강동구', '양재대로'],
#  ['서울', '강동구', '성안로'],
#  ['서울특별시', '강동구', '', '올림픽로'],
#  ['서울', '강동구', '올림픽로'],
#  ['서울', '강동구', '천중로'],
#  ['서울', '강동구', '올림픽로'],
#  ['서울', '동대문구'],
#  ['서울', '동대문구'],
#  ['서울', '동대문구', '고산자로'],
#  ['서울', '동대문구', '왕산로'],
#  ['서울', '동대문구', '이문로'],
#  ['서울', '동대문구', '답십리로'],
#  ['서울', '동대문구', '한천로'],
#  ['서울', '동대문구'],
#  ['서울', '동대문구', '사가정로'],
#  ['서울', '동대문구', '전농로'],
#  ['서울', '동대문구'],
#  ['서울', '동대문구', '망우로'],
#  ['서울', '동대문구', '홍릉로'],
#  ['서울', '동대문구', '', '한천로'],
#  ['서울', '동대문구', '천호대로'],
#  ['서울', '동대문구', '', '한천로'],
#  ['서울', '동대문구', '망우로'],
#  ['경기', '안산시', '단원구'],
#  ['경기', '안산시', '단원구', '성곡로'],
#  ['경기', '안산시', '단원구'],
#  ['경기', '안산시', '단원구', '순환로'],
#  ['경기', '안산시', '단원구'],
#  ['경기', '안산시', '단원구', '고잔로'],
#  ['경기', '안산시', '단원구', '시흥대로'],
# ...

# %%
loc=[]
for i in df_address:
    loc.append(" ".join(i))
loc
a=df.copy()
a["주소"]=loc
df = a
df
# Out:
#        Unnamed: 0     지역                    상호               주소      상표  \
# 0               0  서울특별시  재건에너지 재정제2주유소 고속셀프지점  서울특별시 강동구  천호대로  현대오일뱅크
# 1               1  서울특별시               방아다리주유소       서울 강동구 동남로   SK에너지
# 2               2  서울특별시     현대오일뱅크㈜직영 명일셀프주유소       서울 강동구 고덕로  현대오일뱅크
# 3               3  서울특별시                구천면주유소      서울 강동구 구천면로  현대오일뱅크
# 4               4  서울특별시          대성석유(주)길동주유소           서울 강동구   GS칼텍스
# ...           ...    ...                   ...              ...     ...
# 10983       10983  서울특별시    (주)새서울네트웍스 제이제이주유소           서울 강남구  현대오일뱅크
# 10984       10984  서울특별시                 대청주유소       서울 강남구 개포로   SK에너지
# 10985       10985  서울특별시               SK논현주유소       서울 강남구 논현로   SK에너지
# 10986       10986  서울특별시               갤러리아주유소           서울 강남구   SK에너지
# 10987       10987  서울특별시        (주)만정에너지 삼보주유소      서울 강남구 봉은사로   GS칼텍스
#
#                전화번호 셀프여부  고급휘발유   휘발유    경유  실내등유
# 0       02-487-2030    Y      0  1709  1829     0
# ...

# %%
df = df.drop(columns='Unnamed: 0')
df
# Out:
#           지역                    상호               주소      상표          전화번호  \
# 0      서울특별시  재건에너지 재정제2주유소 고속셀프지점  서울특별시 강동구  천호대로  현대오일뱅크   02-487-2030
# 1      서울특별시               방아다리주유소       서울 강동구 동남로   SK에너지   02-442-5145
# 2      서울특별시     현대오일뱅크㈜직영 명일셀프주유소       서울 강동구 고덕로  현대오일뱅크  02-3428-1739
# 3      서울특별시                구천면주유소      서울 강동구 구천면로  현대오일뱅크   02-441-0536
# 4      서울특별시          대성석유(주)길동주유소           서울 강동구   GS칼텍스   02-474-7222
# ...      ...                   ...              ...     ...           ...
# 10983  서울특별시    (주)새서울네트웍스 제이제이주유소           서울 강남구  현대오일뱅크   02-518-5631
# 10984  서울특별시                 대청주유소       서울 강남구 개포로   SK에너지   02-445-5500
# 10985  서울특별시               SK논현주유소       서울 강남구 논현로   SK에너지   02-511-0955
# 10986  서울특별시               갤러리아주유소           서울 강남구   SK에너지   02-540-4965
# 10987  서울특별시        (주)만정에너지 삼보주유소      서울 강남구 봉은사로   GS칼텍스   02-518-5141
#
#       셀프여부  고급휘발유   휘발유    경유  실내등유
# 0        Y      0  1709  1829     0
# ...

# %%
# 전처리
df_address = df['주소'].str.split().apply(lambda x: x[1])
df_address[df_address == '김해']
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [11], in <cell line: 2>()
#       1 # 전처리
# ----> 2 df_address = df['주소'].str.split().apply(lambda x: x[1])
#       3 df_address[df_address == '김해']
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/series.py:4433, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4323 def apply(
#    4324     self,
#    4325     func: AggFuncType,
#    (...)
#    4328     **kwargs,
#    4329 ) -> DataFrame | Series:
#    4330     """
#    4331     Invoke function on values of Series.
#    4332
#    (...)
#    4431     dtype: float64
#    4432     """
# -> 4433     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/apply.py:1082, in SeriesApply.apply(self)
#    1078 if isinstance(self.f, str):
# ...

# %%
df_address = df['주소'].str.split().apply(lambda x: x[1])
df_address.unique()

# %%
# 종합운동장로, 세종로, 다정북로, 보듬5로, 마음안로, 어울로, 금송로,    국책연구원3로, 다솜로, 소담로, 갈매로, 금남구즉로

# %%
df[df['주소'].str.contains("금남구즉로")]
# Out:
#            지역               상호            주소     상표          전화번호 셀프여부  고급휘발유  \
# 1862    대전광역시            대광주유소  대전 유성구 금남구즉로  S-OIL  042-935-6667    N      0
# 2193  세종특별자치시  삼미상사(주) 보람셀프주유소     세종시 금남구즉로  SK에너지  044-868-7250    Y      0
#
#        휘발유    경유  실내등유
# 1862  1699  1839  1700
# 2193  1735  1865     0
